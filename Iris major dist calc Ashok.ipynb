# 19  1.039062e-15  3.894649e+26  0.000139
# 20  9.692951e-16  4.311822e+26  0.000154

# %%
df.to_csv('ASHOKIRISext.csv')

# %%
df.describe()
# Out:
#                m       F100        deg          d        F60      ratio  \
# count  21.000000  21.000000  21.000000  21.000000  21.000000  21.000000
# mean   14.636667   7.088914   0.243944   7.157709   1.671438   0.235779
# std     8.315282   0.166151   0.138588   4.066388   0.061703   0.006689
# min     1.320000   6.838500   0.022000   0.645514   1.533100   0.221889
# 25%     8.300000   6.957100   0.138333   4.058915   1.650400   0.231806
# 50%    13.940000   7.092700   0.232333   6.817021   1.675000   0.235119
# 75%    21.150000   7.149800   0.352500  10.342898   1.707800   0.241864
# max    28.680000   7.574300   0.478000  14.025264   1.815100   0.249196
#
#                T        B(V,T)             M         Av
# count  21.000000  2.100000e+01  2.100000e+01  21.000000
# mean   24.004919  9.923945e-16  4.077017e+26   0.000145
# std     0.170299  4.231092e-17  1.934756e+25   0.000007
# min    23.647041  9.055956e-16  3.682218e+26   0.000131
# 25%    23.904486  9.670893e-16  3.894649e+26   0.000139
# 50%    23.989245  9.879322e-16  4.116862e+26   0.000147
# 75%    24.160007  1.030834e-15  4.222734e+26   0.000151
# max    24.342977  1.078163e-15  4.360729e+26   0.000156

# %%
from sklearn.metrics import r2_score
plt.style.use("classic")
# %matplotlib inline
mu = np.mean(df['M']*10**-26 )
sigma = np.std(df['M']*10**-26 )
d = df['d']
M = df['M']*10**-26
se = sigma/np.sqrt(21)

 
mymodel = np.poly1d(np.polyfit(d, M, 2))
mymodel1 = np.poly1d(np.polyfit(d,M, 3))
mymodel2 = np.poly1d(np.polyfit(d, M, 4))
mymodel3 = np.poly1d(np.polyfit(d, M, 16))
myline = np.linspace(0.5,14.2,100)
plt.figure(figsize=(10,8))
plt.errorbar(d, M, yerr=se,
           fmt='o',capsize=5,label='error bar',color='r' )
plt.plot(myline, mymodel(myline),ls='--',c='b',label='2nd order')
plt.plot(myline, mymodel1(myline),marker='.',markersize=7,c='k',label='3rd order')
plt.plot(myline, mymodel2(myline),c='g',label='16th order')
#lt.plot(myline, mymodel3(myline),c='black',label='5th order')
plt.legend(loc='best')
print(r2_score(M, mymodel(d)))
print(r2_score(M, mymodel1(d)))
#print(r2_score(M, mymodel2(d)))
print(r2_score(M, mymodel3(d)))
print(se)
plt.xlabel("Extension (pc)",fontsize=16)
plt.ylabel(r" M$_{\mathregular{d}}$$\times 10^{26}$ (kg)",fontsize=16)
plt.savefig('ImadvsM.png' )
# Out:
# 0.28499721556610524
# 0.3611381178376729
# 0.9634463586007789
# 0.04120235123618409

# %%
from sklearn.metrics import r2_score
mu = np.mean(df['T'])
sigma = np.std(df['T'])
d = df['d']
T = df['T']
se = sigma/np.sqrt(21)

 
mymodel = np.poly1d(np.polyfit(d, T, 2))
mymodel1 = np.poly1d(np.polyfit(d,T, 5))
mymodel2 = np.poly1d(np.polyfit(d, T, 10))
#mymodel3 = np.poly1d(np.polyfit(d, T, 5))
myline = np.linspace(0.5,14.2,100)
plt.figure(figsize=(10,8))
plt.errorbar(d, T, yerr=se,
           fmt='o',capsize=5,label='error bar',color='r')
plt.plot(myline, mymodel(myline),ls='--',c='b',label='2nd order')
plt.plot(myline, mymodel1(myline),marker='.',markersize=7,c='k',label='5th order')
plt.plot(myline, mymodel2(myline),c='g',label='10th order')
#plt.plot(myline, mymodel3(myline),c='black',label='5th order')
plt.legend(loc='best')
print(r2_score(T, mymodel(d)))
print(r2_score(T, mymodel1(d)))
print(r2_score(T, mymodel2(d)))
#print(r2_score(T, mymodel3(d)))
print(se)
plt.xlabel("Extension (pc)",fontsize=16)
plt.ylabel(r"T$_{\mathregular{d}}$ (K)",fontsize=16)
plt.savefig('ImadvsT.png' )
# Out:
# 0.09087187762585769
# 0.5990354703079759
# 0.8534851861184426
# 0.03626662455146275

# %%
from sklearn.metrics import r2_score
mu = np.mean(df['B(V,T)']*10**16)
sigma = np.std(df['B(V,T)']*10**16)
d = df['d']
B = df['B(V,T)']*10**16
se = sigma/np.sqrt(21)

 
mymodel = np.poly1d(np.polyfit(d, B, 2))
mymodel1 = np.poly1d(np.polyfit(d,B, 3))
mymodel2 = np.poly1d(np.polyfit(d, B, 4))
mymodel3 = np.poly1d(np.polyfit(d, B, 9))
myline = np.linspace(0.5,14.2,100)
plt.figure(figsize=(10,8))
plt.errorbar(d, B, yerr=se,
           fmt='o',capsize=5,label='error bar',color='r' )
plt.plot(myline, mymodel(myline),ls='--',c='b',label='2nd order')
#plt.plot(myline, mymodel1(myline),c='c',label='3rd order')
plt.plot(myline, mymodel2(myline),marker='.',markersize=7,c='g',label='4th order')
plt.plot(myline, mymodel3(myline),c='black',label='9th order')
plt.legend(loc='best')
print(r2_score(B, mymodel(d)))
print(r2_score(B, mymodel1(d)))
print(r2_score(B, mymodel2(d)))
print(r2_score(B, mymodel3(d)))
print(se)
plt.xlabel("Extension (pc)",fontsize=16)
plt.ylabel(r"B($\nu$,T)$\times 10^{-16}$ (Wm$^{-2}$sr$^{-1}$Hz$^{-1}$)" ,fontsize=16)
plt.savefig('ImadvsB.png' )
# Out:
# 0.09286803830965784
# 0.09394028292468459
# 0.34360874117480034
# 0.8566447728338775
# 0.09010486049674368

# %%
from sklearn.metrics import r2_score
mu = np.mean(df['F100'] )
sigma = np.std(df['F100'] )
d = df['d']
F100 = df['F100'] 
se = sigma/np.sqrt(21)

 
mymodel = np.poly1d(np.polyfit(d, F100, 2))
mymodel1 = np.poly1d(np.polyfit(d,F100, 3))
mymodel2 = np.poly1d(np.polyfit(d, F100, 4))
 
myline = np.linspace(0.5,14.2,100)
plt.figure(figsize=(10,8))
plt.errorbar(d, F100, yerr=se,
           fmt='o',capsize=5,label='error bar',color='r' )
plt.plot(myline, mymodel(myline),marker='.',markersize=7,c='b',label='2nd order')
plt.plot(myline, mymodel1(myline),ls='--',c='k',label='3rd order')
plt.plot(myline, mymodel2(myline),c='g',label='4th order')
plt.legend(loc='best')
print(r2_score(F100, mymodel(d)))
print(r2_score(F100, mymodel1(d)))
print(r2_score(F100, mymodel2(d)))
print(se)
plt.xlabel("Extension (pc)",fontsize=16)
plt.ylabel(r"F100 $\mu$m (MJy/sr)",fontsize=16)
plt.savefig('ImadvsF100.png' )
# Out:
# 0.3528455253951587
# 0.6366247265639718
# 0.8971696049280917
# 0.035383369324429065
