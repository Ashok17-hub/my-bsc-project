# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
df = pd.read_csv('IRISnew.csv')
df
# Out:
#       h   m      s          RA   d  arc m  arc s        DEC     F60  h.1  m.1  \
# 0    12  40  43.20  190.180000 -41     23   43.1 -40.604694  1.8144   12   40
# 1    12  40  43.21  190.180042 -41     25    5.9 -40.581694  1.7331   12   40
# 2    12  40  42.26  190.176083 -41     26   25.1 -40.559694  1.7520   12   40
# 3    12  40  35.84  190.149333 -41     21   55.2 -40.634667  1.7973   12   40
# 4    12  40  35.52  190.148000 -41     23   28.8 -40.608667  1.7482   12   40
# ..   ..  ..    ...         ...  ..    ...    ...        ...     ...  ...  ...
# 159  12  38  29.24  189.621833 -41     20   36.5 -40.656528  1.7689   12   38
# 160  12  38  24.71  189.602958 -41     11   32.7 -40.807583  1.7770   12   38
# 161  12  38  23.71  189.598792 -41     12   48.2 -40.786611  1.7690   12   38
# 162  12  38  23.35  189.597292 -41     14   25.4 -40.759611  1.7483   12   38
# 163  12  38  22.99  189.595792 -41     15   55.3 -40.734639  1.7902   12   38
#
# ...

# %%
se= np.std(df['T'])/np.sqrt(164)
se
# Out:
# 0.012190451416154213

# %%
ratio = df.F60/df.F100
df["ratio"] = ratio
df
# Out:
#       h   m      s          RA   d  arc m  arc s        DEC     F60  h.1  ...  \
# 0    12  40  43.20  190.180000 -41     23   43.1 -40.604694  1.8144   12  ...
# 1    12  40  43.21  190.180042 -41     25    5.9 -40.581694  1.7331   12  ...
# 2    12  40  42.26  190.176083 -41     26   25.1 -40.559694  1.7520   12  ...
# 3    12  40  35.84  190.149333 -41     21   55.2 -40.634667  1.7973   12  ...
# 4    12  40  35.52  190.148000 -41     23   28.8 -40.608667  1.7482   12  ...
# ..   ..  ..    ...         ...  ..    ...    ...        ...     ...  ...  ...
# 159  12  38  29.24  189.621833 -41     20   36.5 -40.656528  1.7689   12  ...
# 160  12  38  24.71  189.602958 -41     11   32.7 -40.807583  1.7770   12  ...
# 161  12  38  23.71  189.598792 -41     12   48.2 -40.786611  1.7690   12  ...
# 162  12  38  23.35  189.597292 -41     14   25.4 -40.759611  1.7483   12  ...
# 163  12  38  22.99  189.595792 -41     15   55.3 -40.734639  1.7902   12  ...
#
# ...

# %%
Temp = -96/(np.log(df.ratio*0.6**5))
Temp
# Out:
# 0      24.112022
# 1      23.905211
# 2      23.870019
# 3      24.042235
# 4      24.055905
#          ...
# 159    23.907100
# 160    23.956061
# 161    24.042714
# 162    23.931873
# 163    24.033762
# Name: ratio, Length: 164, dtype: float64

# %%
T=df['T']
c = 3.0E+8 
h = 6.62E-34
kb = 1.38E-23
lam = 1.0E-4
a = np.exp(h*c/(lam*kb*df['T']))
b = 1/(a-1)
planck = 2*h*c*b/lam**3
planck
# Out:
# 0      1.018655e-15
# 1      9.672663e-16
# 2      9.586985e-16
# 3      1.001115e-15
# 4      1.004534e-15
#            ...
# 159    9.677276e-16
# 160    9.797365e-16
# 161    1.001234e-15
# 162    9.737915e-16
# 163    9.989991e-16
# Name: T, Length: 164, dtype: float64

# %%
df.describe()
# Out:
#            h           m           s          RA      d       arc m  \
# count  164.0  164.000000  164.000000  164.000000  164.0  164.000000
# mean    12.0   38.975610   30.303476  189.870167  -41.0   19.560976
# std      0.0    0.717453   17.233696    0.156661    0.0    4.939133
# min     12.0   38.000000    0.820000  189.595792  -41.0   10.000000
# 25%     12.0   38.000000   16.252500  189.734073  -41.0   16.000000
# 50%     12.0   39.000000   31.260000  189.861187  -41.0   20.000000
# 75%     12.0   39.000000   44.957500  189.993875  -41.0   24.000000
# max     12.0   40.000000   59.830000  190.180042  -41.0   29.000000
#
#             arc s         DEC         F60    h.1  ...         s.1    d.1  \
# count  164.000000  164.000000  164.000000  164.0  ...  164.000000  164.0
# mean    29.700610  -40.665734    1.697777   12.0  ...   30.303476  -41.0
# std     17.595484    0.082349    0.062903    0.0  ...   17.233696    0.0
# ...

# %%
RA = df['RA'] 
DEC= df['DEC']
 
plt.figure(figsize=(10,8))
plt.scatter(RA,DEC,c='r')
plt.xlim(190.2,189.5)
plt.xlabel('RA (deg.)',fontsize=16 )
plt.ylabel('Dec. (deg.)' ,fontsize=16 )
plt.tick_params(direction='in')
plt.savefig('Scatter plot I.png' )

# %%
from scipy import stats
F60 = df['F60']
F100= df['F100']
plt.figure(figsize=(10,8))
slope, intercept, r, p, std_err = stats.linregress(F100, F60)
def myfunc(F100):
  return slope * F100 + intercept
mymodel = list(map(myfunc, F100))
plt.scatter(F100,F60,c='r')
plt.plot(F100, mymodel, c = 'g', linewidth = 1) 
plt.legend(["bestfit line","flux"],loc="upper left")
plt.xlabel('F100 $\mu$m (MJy/sr)',fontsize=16 )
plt.ylabel('F60 $\mu$m (MJy/sr)' ,fontsize=16)
plt.tick_params(direction='in')
plt.savefig('BFI.png' )
print(slope)
print(intercept)
print(r)
print(p)
# Out:
# 0.21798702375157147
# 0.1197873181405491
# 0.7154511547126147
# 5.137977162853373e-27

# %%
F60 = df['F60']
F100= df['F100']
plt.figure(figsize=(10,8))
plt.scatter(F100,F60,c='r')
plt.legend(["flux"],loc="upper left")
plt.xlabel('F100 $\mu$m (MJy/sr)',fontsize=16)
plt.ylabel('F60 $\mu$m (MJy/sr)',fontsize=16)
plt.tick_params(direction='in')
plt.savefig('ScI.png' )

# %%
RA = df['RA']
DEC= df['DEC']
F100 = df['F100']

# %%
plt.figure(figsize=(10,8))
plt.hexbin(RA, DEC, F100, gridsize=(20),cmap='nipy_spectral')
plt.colorbar().set_label(label='F100 $\mu$m (MJy/sr)',size=16  )
plt.xlabel("RA (deg.)",fontsize=16)
plt.ylabel("Dec. (deg.)",fontsize=16)
plt.xlim(190.2,189.5)
plt.tick_params(direction='in')
plt.savefig('F100hI.png' )    
plt.figure(figsize=(10,8))
plt.tricontourf(RA, DEC, F100, levels=8, cmap='nipy_spectral')
plt.colorbar().set_label(label='F100 $\mu$m (MJy/sr)',size=16)
plt.xlim(190.2,189.5)
plt.tick_params(direction= 'in')
plt.xlabel('RA (deg.)',fontsize=16)
plt.ylabel('Dec. (deg.)',fontsize=16)
#plt.xticks(fontweight="bold")
#plt.yticks(fontweight="bold")
plt.savefig('F100cI.png' )

# %%
RA = df['RA']
DEC= df['DEC']
F60 = df['F60']

# %%
plt.figure(figsize=(10,8))
plt.hexbin(RA, DEC, F60, gridsize=(20),cmap='nipy_spectral')
plt.colorbar().set_label(label='F60 $\mu$m (MJy/sr)',size=16)
plt.xlabel("RA (deg.)" ,fontsize=16)
plt.ylabel("Dec. (deg.)" ,fontsize=16)
plt.tick_params(direction='in')
plt.xlim(190.2,189.5)
plt.savefig('F60hI.png' )    
plt.figure(figsize=(10,8))
plt.tricontourf(RA, DEC, F60, levels=8, cmap='nipy_spectral')
plt.colorbar().set_label(label='F60 $\mu$m (MJy/sr)',size=16)
plt.xlim(190.2,189.5)
plt.xlabel('RA (deg.)',fontsize=16)
plt.ylabel('Dec. (deg.)',fontsize=16)
plt.tick_params(direction='in')
plt.savefig('F60cI.png' )

# %%
RA = df['RA']
DEC= df['DEC']
M = df['M']*10**-26

# %%
plt.figure(figsize=(10,8))
plt.hexbin(RA, DEC, M, gridsize=(20),cmap='nipy_spectral')
plt.colorbar().set_label(label=r'M$_{\mathregular{d}}$$\times 10^{26}$ (Kg)',size=16 )
plt.xlabel("RA (deg.)",fontsize=16)
plt.ylabel("Dec. (deg.)",fontsize=16 )
plt.xlim(190.2,189.5)
plt.savefig('MhI.png' )
plt.tick_params(direction='in')
plt.figure(figsize=(10,8))
plt.tricontourf(RA, DEC, M, levels=8, cmap='nipy_spectral')
plt.colorbar().set_label(label=r'M$_{\mathregular{d}}$$\times 10^{26}$ (Kg)',size=16 )
plt.xlim(190.2,189.5)
plt.xlabel('RA (deg.)',fontsize=16 )
plt.ylabel('Dec. (deg.)' ,fontsize=16)
plt.tick_params(direction='in')
plt.savefig('McI.png' )

# %%
RA = df['RA']
DEC= df['DEC']
T = df['T']

# %%
plt.figure(figsize=(10,8))
plt.hexbin(RA, DEC, T, gridsize=(20),cmap='nipy_spectral')
plt.colorbar().set_label(label=r'T$_{\mathregular{d}}$ (K)',size=16)
plt.xlabel("RA (deg.)" ,fontsize=16)
plt.ylabel("Dec. (deg.)",fontsize=16)
plt.xlim(190.2,189.5)
plt.tick_params(direction='in')
plt.savefig('ThI.png' )    
plt.figure(figsize=(10,8))
plt.tricontourf(RA, DEC, T, levels=8, cmap='nipy_spectral')
plt.colorbar().set_label(label=r'T$_{\mathregular{d}}$ (K)',size=16)
plt.xlim(190.2,189.5)
plt.tick_params(direction='in')
plt.xlabel('RA (deg.)',fontsize=16)
plt.ylabel('Dec. (deg.)',fontsize=1)
plt.savefig('TcI.png' )

# %%
RA = df['RA'] 
DEC= df['DEC'] 
B = df['B(V,T)']*10**15

# %%
plt.figure(figsize=(10,8))
plt.hexbin(RA, DEC, B, gridsize=(20),cmap='nipy_spectral')
plt.colorbar().set_label(label=r"B($\nu$,T)$\times 10^{-16}$ (Wm$^{-2}$sr$^{-1}$Hz$^{-1}$)",size=16)
plt.xlabel("RA (deg.)",fontsize=16)
plt.ylabel("Dec. (deg.)",fontsize=16)
plt.xlim(190.2,189.5)
plt.tick_params(direction='in')
plt.savefig('BhI.png' )    
plt.figure(figsize=(10,8))
plt.tricontourf(RA, DEC, B, levels=8, cmap='nipy_spectral')
plt.colorbar().set_label(label= r"B($\nu$,T)$\times 10^{-16}$ (Wm$^{-2}$sr$^{-1}$Hz$^{-1}$)",size=16)
plt.xlim(190.2,189.5)
plt.xlabel('RA (deg.)',fontsize=16)
plt.ylabel('Dec. (deg.)',fontsize=16)
plt.tick_params(direction='in')
plt.savefig('BcI.png' )

# %%
plt.figure()
plt.subplot(111, projection="lambert")
#plt.title("lambert")
plt.plot(df.RA, df.DEC,'.')
plt.grid(True)
plt.savefig('IP.png')

# %%
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from scipy import optimize as som
plt.style.use('classic')
# %matplotlib inline

# %%
np.random.seed(19680801)# Fixing random state for reproducibility
mu = np.mean(df['T'] )   
sigma = np.std(df['T']  )  
T = df['T'] 

plt.figure(figsize=(10,8))
n, bins, patches = plt.hist(T,  bins=20,density=True,color='springgreen')
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5* (1 / sigma * (bins - mu))**2))
plt.plot(bins, y, '--',linewidth=3,c='r')
plt.legend(["Gaussian fit"],loc='upper left')
plt.xlabel(r"T$_{\mathregular{d}}$ (K)",fontsize=16)
plt.ylabel("Probability density function",fontsize=16 )
plt.savefig('GFMT.png' )

# %%
np.random.seed(19680801)
mu = np.mean(df['F100'])   
sigma = np.std(df['F100'])  
F100 = df['F100']
 
plt.figure(figsize=(10,8))
n, bins, patches = plt.hist(F100,  bins=20, density=True,color='springgreen')
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))

plt.plot(bins, y,'--' ,lw=3,c='r',label = 'Gaussian fit')

 
plt.legend(loc='upper left')
plt.xlabel("F100 $\mu$m  (MJy/sr)",fontsize=16)
plt.ylabel("Probability density function",fontsize=16)
plt.savefig('GFF100I.png' )

# %%
np.random.seed(19680801)
mu = np.mean(df['B(V,T)']*10**16)   
sigma = np.std(df['B(V,T)']*10**16)  
B = df['B(V,T)']*10**16
plt.figure(figsize=(10,8))
n, bins, patches = plt.hist(B,  bins=20, density=True,color='springgreen')
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
 
plt.plot(bins, y, '--',lw=3,c='r')
plt.legend(["Gaussian fit"],loc='upper left')
plt.xlabel(r"B($\nu$,T)$\times 10^{-16}$ (Wm$^{-2}$sr$^{-1}$Hz$^{-1}$)",fontsize=16)
plt.ylabel("Probability density function",fontsize=16)
plt.savefig('GFPlanckI.png' )

# %%
np.random.seed(19680801)
mu = np.mean(df['F60'])   
sigma = np.std(df['F60'])  
F60 = df['F60']
 
plt.figure(figsize=(10,8))
n, bins, patches = plt.hist(F60,  bins=20, density=True,color='springgreen')
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))

plt.plot(bins, y, '--',lw=3,c='r')
plt.legend(["Gaussian fit"],loc='upper left')
 
plt.xlabel("F60 $\mu$m (MJy/sr)",fontsize=16)
plt.ylabel("Probability density function",fontsize=16 )
plt.savefig('GFF60I.png' )

# %%
np.random.seed(19680801)
mu = np.mean(df['M']*10**-26)   
sigma = np.std(df['M']*10**-26)  
M = df['M']*10**-26
plt.figure(figsize=(10,8))
n, bins, patches = plt.hist(M,  bins=20, density=True,color='springgreen')
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins, y,'--' ,lw=3,c='r',label = 'Gaussian fit')
plt.legend(loc='upper left')
plt.xlabel(r"M$_{\mathregular{d}}$$\times 10^{26}$ (Kg)",fontsize=16)
plt.ylabel("Probability density function",fontsize=16)
plt.savefig('GFMI.png' )

# %%
plt.figure()
plt.subplot(111, projection="aitoff")
plt.title("Aitoff")
plt.scatter(RA,DEC)

plt.grid(True)
plt.savefig('Map.png')

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize = [8,8])

ax = fig.add_subplot(111, projection='3d')
ax.scatter(df.RA, df.DEC, df.F60,'.',color='r')
plt.xlim(190.2,189.5)
plt.xlabel('Longitude', color='b', fontsize=16)
plt.ylabel('Latitude', color='b', fontsize=16)
plt.savefig('3DAll.png')

# %%
F100=df['F100']*1.25664**-19
B = df['B(V,T)']*10**15
Tau100 = F100/B
Tau100
# Out:
# 0      0.096731
# 1      0.100715
# 2      0.103333
# 3      0.098631
# 4      0.095393
#          ...
# 159    0.102714
# 160    0.101086
# 161    0.097059
# 162    0.100467
# 163    0.098588
# Length: 164, dtype: float64

# %%
av = 1-np.exp(-Tau100/641.3)
df['Av']= av
df
# Out:
#       h   m      s          RA   d  arc m  arc s        DEC     F60  h.1  ...  \
# 0    12  40  43.20  190.180000 -41     23   43.1 -40.604694  1.8144   12  ...
# 1    12  40  43.21  190.180042 -41     25    5.9 -40.581694  1.7331   12  ...
# 2    12  40  42.26  190.176083 -41     26   25.1 -40.559694  1.7520   12  ...
# 3    12  40  35.84  190.149333 -41     21   55.2 -40.634667  1.7973   12  ...
# 4    12  40  35.52  190.148000 -41     23   28.8 -40.608667  1.7482   12  ...
# ..   ..  ..    ...         ...  ..    ...    ...        ...     ...  ...  ...
# 159  12  38  29.24  189.621833 -41     20   36.5 -40.656528  1.7689   12  ...
# 160  12  38  24.71  189.602958 -41     11   32.7 -40.807583  1.7770   12  ...
# 161  12  38  23.71  189.598792 -41     12   48.2 -40.786611  1.7690   12  ...
# 162  12  38  23.35  189.597292 -41     14   25.4 -40.759611  1.7483   12  ...
# 163  12  38  22.99  189.595792 -41     15   55.3 -40.734639  1.7902   12  ...
#
# ...

# %%
df.to_csv('ASHOKIRIS.csv')

# %%
from scipy import stats
Av = df['Av']*10**4
T = df['T']
plt.figure(figsize=(10,8))
slope, intercept, r, p, std_err = stats.linregress(Av, T)
def myfunc(Av):
  return slope *  Av + intercept
mymodel = list(map(myfunc,Av ))
plt.scatter(Av,T,c='r')
plt.plot(Av, mymodel, c = 'g', linewidth = 1,label='best fit line') 
plt.legend(loc="upper right")
plt.xlabel(r'A$_{\mathregular{V}}$ $\times 10^{-4}$ (mag) ',fontsize=16 )
plt.ylabel('T$_{\mathregular{d}}$ (K)' ,fontsize=16)
plt.savefig('BFIE.png')  
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
print(slope)
print(intercept)
print(r)
print(p)
# Out:
# -1.7232512030782754
# 26.5521589692151
# -0.8224413166755931
# 1.5480412135968914e-41

# %%
mu=np.mean(df['Av']*10**4)
print(mu)
# Out:
# 1.496303289209625

# %%
std=np.std(df['M'])
std
# Out:
# 2.089467737931495e+25
